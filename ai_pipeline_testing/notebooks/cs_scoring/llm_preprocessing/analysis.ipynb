# %% [markdown]
# # LLM Preprocessing Results – Attribute Span Tagging
#
# This notebook:
# - Runs the preprocessing (if needed)
# - Loads the results from `results/`
# - Lets us inspect some examples

# %%
import os
import pandas as pd
from pipeline import run_preprocessing

# Go 3 folders up from the notebook's folder
project_root = os.path.abspath(os.path.join(os.getcwd(), "..", "..", ".."))

print("Correct project root resolved as:", project_root)

infile = os.path.join(
    project_root,
    "data", "raw", "synthetic",
    "B2B_Customer_Feedback_Dataset.xlsx"
)

results_dir = os.path.join(os.getcwd(), "results")

excel_path = os.path.join(results_dir, "b2b_feedback_with_attribute_spans.xlsx")
flat_path = os.path.join(results_dir, "b2b_feedback_attribute_spans_flat.csv")
jsonl_path = os.path.join(results_dir, "b2b_feedback_attribute_spans.jsonl")

comment_col = "Comment"
# Out:
# Correct project root resolved as: c:\Users\tengc\Downloads\develop_ai_pipelines_testing\ai_pipeline_testing

# %%
if not (os.path.exists(excel_path) and os.path.exists(flat_path) and os.path.exists(jsonl_path)):
    print("Results not found – running preprocessing now...")
    df, flat_df = run_preprocessing(
        infile=infile,
        comment_col=comment_col,
        id_col=None,  # or your ID col if you have one
        out_excel=excel_path,
        out_flat=flat_path,
        out_jsonl=jsonl_path,
        model="gpt-4.1-mini",
        limit=None,  # change to small int for quick test
    )
else:
    print("Results already exist – loading from disk...")
    df = pd.read_excel(excel_path)
    flat_df = pd.read_csv(flat_path)

len(df), len(flat_df)
# Out:
# Results not found – running preprocessing now...
# 100%|██████████| 50/50 [02:05<00:00,  2.51s/it]
# (50, 123)

# %%
# Show a few original comments + JSON span mapping
df[["Comment", "llm_spans_json"]].head(10)
# Out:
#                                              Comment  \
# 0                                            Status?
# 1  As per our call just now pls rush the 6 inch A...
# 2  MTC received but cert date shows March 2024, o...
# 3  Can faster or not? Client side keep asking me ...
# 4  Good support from your Katherine during LKG pr...
# 5  Wrong item sent again. This is 3rd time alread...
# 6  Refer to my email dated 15 Oct regarding the m...
# 7  Driver cannot find our Pioneer Road location. ...
# 8  Hi the valve you quoted is for freshwater syst...
# 9  Flanges received yesterday, quality looks good...
#
#                                       llm_spans_json
# 0  {"comment": "Status?", "attributes": {"Deliver...
# 1  {"comment": "As per our call just now pls rush...
# 2  {"comment": "MTC received but cert date shows ...
# 3  {"comment": "Can faster or not? Client side ke...
# 4  {"comment": "Good support from your Katherine ...
# 5  {"comment": "Wrong item sent again. This is 3r...
# 6  {"comment": "Refer to my email dated 15 Oct re...
# 7  {"comment": "Driver cannot find our Pioneer Ro...
# 8  {"comment": "Hi the valve you quoted is for fr...
# 9  {"comment": "Flanges received yesterday, quali...

# %%
# One row per (comment, attribute, span)
flat_df.head(20)
# Out:
#     row_index                                            comment attribute  \
# 0           0                                            Status?  Delivery
# 1           1  As per our call just now pls rush the 6 inch A...   Product
# 2           1  As per our call just now pls rush the 6 inch A...  Delivery
# 3           3  Can faster or not? Client side keep asking me ...   Product
# 4           3  Can faster or not? Client side keep asking me ...  Delivery
# 5           4  Good support from your Katherine during LKG pr...   Service
# 6           4  Good support from your Katherine during LKG pr...   Service
# 7           6  Refer to my email dated 15 Oct regarding the m...   Product
# 8           6  Refer to my email dated 15 Oct regarding the m...   Service
# 9           7  Driver cannot find our Pioneer Road location. ...  Delivery
# 10          8  Hi the valve you quoted is for freshwater syst...   Product
# 11          8  Hi the valve you quoted is for freshwater syst...   Product
# 12          8  Hi the valve you quoted is for freshwater syst...   Product
# 13          8  Hi the valve you quoted is for freshwater syst...   Product
# 14          9  Flanges received yesterday, quality looks good...   Product
# 15          9  Flanges received yesterday, quality looks good...   Product
# 16          9  Flanges received yesterday, quality looks good...   Product
# 17          9  Flanges received yesterday, quality looks good...  Delivery
# 18          9  Flanges received yesterday, quality looks good...  Delivery
# 19         10  Boss asking for update on PO CC-2847. Can advi...   Product
#
#                                             text_span
# 0                                             Status?
# 1                             6 inch ANSI 150 flanges
# 2   rush the 6 inch ANSI 150 flanges to Tuas site ...
# 3                                         DI fittings
# 4                   Need the DI fittings by COB today
# 5                    Good support from your Katherine
# 6                                  same service level
# 7                                      manhole covers
# 8                      Still no reply from your side?
# 9       Driver cannot find our Pioneer Road location.
# 10                                              valve
# 11                                  freshwater system
# 12                                           seawater
# 13                                corrosion resistant
# 14                                            Flanges
# 15                                 quality looks good
# 16                            coating finish is clean
# 17                                 received yesterday
# 18                                      fast delivery
# 19                                         PO CC-2847

# %%
# Optional: confirm JSONL content
with open(jsonl_path, "r", encoding="utf-8") as f:
    for i, line in enumerate(f):
        if i >= 5:
            break
        print(line.strip())
# Out:
# {"comment": "Status?", "attributes": {"Delivery": ["Status?"]}}
# {"comment": "As per our call just now pls rush the 6 inch ANSI 150 flanges to Tuas site by 3pm today. Foreman waiting.", "attributes": {"Product": ["6 inch ANSI 150 flanges"], "Delivery": ["rush the 6 inch ANSI 150 flanges to Tuas site by 3pm today"]}}
# {"comment": "MTC received but cert date shows March 2024, our PO is Feb 2024. Which batch is this? Pls clarify asap.", "attributes": {}}
# {"comment": "Can faster or not? Client side keep asking me already. Need the DI fittings by COB today if not project delay.", "attributes": {"Product": ["DI fittings"], "Delivery": ["Need the DI fittings by COB today"]}}
# {"comment": "Good support from your Katherine during LKG project shutdown last month. Hope can maintain same service level for upcoming Jurong Island works.", "attributes": {"Service": ["Good support from your Katherine", "same service level"]}}
